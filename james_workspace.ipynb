# %%
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
from matplotlib import pyplot

# %matplotlib inline

# %%
adidas_path = 'Resources/Round 4 Year_Adidas_Sales_Data_Monthly_Category_Summary.csv'
adidas_df = pd.read_csv(adidas_path,
                          index_col='Invoice Date',
                          parse_dates=True,
                          date_format="dateutil")

# %%
display(adidas_df.head())
display(adidas_df.tail())
# Out:
#               Year  Month_Number Month_Name     Region     State      City  \
# Invoice Date
# 2020-01-01    2020             1        Jan  Northeast  New York  New York
# 2020-01-02    2020             1        Jan  Northeast  New York  New York
# 2020-01-03    2020             1        Jan  Northeast  New York  New York
# 2020-01-04    2020             1        Jan  Northeast  New York  New York
# 2020-01-05    2020             1        Jan  Northeast  New York  New York
#
#                        Category Subcategory                    Product  \
# Invoice Date
# 2020-01-01      Street Footwear       Men's      Men's Street Footwear
# 2020-01-02    Athletic Footwear       Men's    Men's Athletic Footwear
# 2020-01-03      Street Footwear     Women's    Women's Street Footwear
# 2020-01-04    Athletic Footwear     Women's  Women's Athletic Footwear
# 2020-01-05              Apparel       Men's              Men's Apparel
#
#               Price per Unit  Units Sold  Total Sales  Profit per Unit  \
# Invoice Date
# 2020-01-01              50.0        1200        60000            25.00
# 2020-01-02              50.0        1000        50000            15.00
# 2020-01-03              40.0        1000        40000            14.00
# 2020-01-04              45.0         850        38250            15.75
# 2020-01-05              60.0         900        54000            18.00
#
#               Operating Margin  Total Operating Profit Year-Month
# Invoice Date
# 2020-01-01                0.50                 30000.0    2020-01
# 2020-01-02                0.30                 15000.0    2020-01
# 2020-01-03                0.35                 14000.0    2020-01
# 2020-01-04                0.35                 13387.5    2020-01
# 2020-01-05                0.30                 16200.0    2020-01
#               Year  Month_Number Month_Name     Region          State  \
# Invoice Date
# 2021-01-24    2021             1        Jan  Northeast  New Hampshire
# 2021-01-24    2021             1        Jan  Northeast  New Hampshire
# 2021-02-22    2021             2        Feb  Northeast  New Hampshire
# 2021-02-22    2021             2        Feb  Northeast  New Hampshire
# 2021-02-22    2021             2        Feb  Northeast  New Hampshire
#
#                     City           Category Subcategory  \
# Invoice Date
# 2021-01-24    Manchester            Apparel       Men's
# 2021-01-24    Manchester            Apparel     Women's
# 2021-02-22    Manchester    Street Footwear       Men's
# 2021-02-22    Manchester  Athletic Footwear       Men's
# 2021-02-22    Manchester    Street Footwear     Women's
#
#                               Product  Price per Unit  Units Sold  \
# Invoice Date
# 2021-01-24              Men's Apparel            50.0          64
# 2021-01-24            Women's Apparel            41.0         105
# 2021-02-22      Men's Street Footwear            41.0         184
# 2021-02-22    Men's Athletic Footwear            42.0          70
# 2021-02-22    Women's Street Footwear            29.0          83
#
#               Total Sales  Profit per Unit  Operating Margin  \
# Invoice Date
# 2021-01-24           3200            14.00              0.28
# 2021-01-24           4305            13.12              0.32
# 2021-02-22           7544            15.17              0.37
# 2021-02-22           2940            17.64              0.42
# 2021-02-22           2407             7.83              0.27
#
#               Total Operating Profit Year-Month
# Invoice Date
# 2021-01-24                    896.00    2021-01
# 2021-01-24                   1377.60    2021-01
# 2021-02-22                   2791.28    2021-02
# 2021-02-22                   1234.80    2021-02
# 2021-02-22                    649.89    2021-02

# %%
monthly_temps_path = 'Resources/avg_temps_cleaned.csv'
monthly_temps_df = pd.read_csv(monthly_temps_path,
                               index_col='State')

# %%
display(monthly_temps_df.head())
display(monthly_temps_df.tail())
# Out:
#          Year  Month  Average Temp
# State
# Alabama  2020      1          50.4
# Alabama  2020      2          50.2
# Alabama  2020      3          57.2
# Alabama  2020      4          62.8
# Alabama  2020      5          65.4
#          Year  Month  Average Temp
# State
# Wyoming  2021      8          67.1
# Wyoming  2021      9          61.1
# Wyoming  2021     10          51.0
# Wyoming  2021     11          40.2
# Wyoming  2021     12          31.3

# %%
adidas_df.columns
# Out:
# Index(['Year', 'Month_Number', 'Month_Name', 'Region', 'State', 'City',
#        'Category', 'Subcategory', 'Product', 'Price per Unit', 'Units Sold',
#        'Total Sales', 'Profit per Unit', 'Operating Margin',
#        'Total Operating Profit', 'Year-Month'],
#       dtype='object')

# %%
adidas_df = adidas_df.reset_index()
adidas_cleaned_james = adidas_df.drop(['City','Price per Unit', 'Profit per Unit','Month_Name', 'Invoice Date', 'Operating Margin', 'Total Operating Profit'],axis=1)
adidas_cleaned_james = adidas_cleaned_james.set_index('Region')
adidas_cleaned_james
# Out:
#            level_0  index  Year  Month_Number          State  \
# Region
# Northeast        0      0  2020             1       New York
# Northeast        1      1  2020             1       New York
# Northeast        2      2  2020             1       New York
# Northeast        3      3  2020             1       New York
# Northeast        4      4  2020             1       New York
# ...            ...    ...   ...           ...            ...
# Northeast     9643   9643  2021             1  New Hampshire
# Northeast     9644   9644  2021             1  New Hampshire
# Northeast     9645   9645  2021             2  New Hampshire
# Northeast     9646   9646  2021             2  New Hampshire
# Northeast     9647   9647  2021             2  New Hampshire
#
#                     Category Subcategory                    Product  \
# Region
# Northeast    Street Footwear       Men's      Men's Street Footwear
# Northeast  Athletic Footwear       Men's    Men's Athletic Footwear
# Northeast    Street Footwear     Women's    Women's Street Footwear
# Northeast  Athletic Footwear     Women's  Women's Athletic Footwear
# Northeast            Apparel       Men's              Men's Apparel
# ...                      ...         ...                        ...
# Northeast            Apparel       Men's              Men's Apparel
# Northeast            Apparel     Women's            Women's Apparel
# Northeast    Street Footwear       Men's      Men's Street Footwear
# Northeast  Athletic Footwear       Men's    Men's Athletic Footwear
# Northeast    Street Footwear     Women's    Women's Street Footwear
#
#            Units Sold  Total Sales Year-Month
# Region
# Northeast        1200        60000    2020-01
# Northeast        1000        50000    2020-01
# Northeast        1000        40000    2020-01
# Northeast         850        38250    2020-01
# Northeast         900        54000    2020-01
# ...               ...          ...        ...
# Northeast          64         3200    2021-01
# Northeast         105         4305    2021-01
# Northeast         184         7544    2021-02
# Northeast          70         2940    2021-02
# Northeast          83         2407    2021-02
#
# [9648 rows x 11 columns]
